# %%
# Rule string from log.csv
s = "0,1,0,0,0,3,2,0,2,1,2,0,3,2,2,3,1,1,3,3,0,3,0,3,0,1,0,0,2,2,2,2,0,1,3,2,0,3,1,3,0,2,3,1,3,2,2,2,0,3,0,2,0,3,3,2,1,3,2,3,3,1,2,3"

rule = [int(x) for x in s.split(',')]
symbols = ['0','P','R','B']

for l in range(4):
    for c in range(4):
        for r in range(4):
            next_state = rule[(l*16) + (c*4) + r]
            print(f"{l}{c}{r}:{next_state} ({symbols[l]}{symbols[c]}{symbols[r]}) → {next_state} ({symbols[next_state]})")
# Out:
# 000:0 (000) → 0 (0)
# 001:1 (00P) → 1 (P)
# 002:0 (00R) → 0 (0)
# 003:0 (00B) → 0 (0)
# 010:0 (0P0) → 0 (0)
# 011:3 (0PP) → 3 (B)
# 012:2 (0PR) → 2 (R)
# 013:0 (0PB) → 0 (0)
# 020:2 (0R0) → 2 (R)
# 021:1 (0RP) → 1 (P)
# 022:2 (0RR) → 2 (R)
# 023:0 (0RB) → 0 (0)
# 030:3 (0B0) → 3 (B)
# 031:2 (0BP) → 2 (R)
# 032:2 (0BR) → 2 (R)
# 033:3 (0BB) → 3 (B)
# 100:1 (P00) → 1 (P)
# 101:1 (P0P) → 1 (P)
# 102:3 (P0R) → 3 (B)
# 103:3 (P0B) → 3 (B)
# 110:0 (PP0) → 0 (0)
# 111:3 (PPP) → 3 (B)
# 112:0 (PPR) → 0 (0)
# 113:3 (PPB) → 3 (B)
# 120:0 (PR0) → 0 (0)
# 121:1 (PRP) → 1 (P)
# 122:0 (PRR) → 0 (0)
# 123:0 (PRB) → 0 (0)
# 130:2 (PB0) → 2 (R)
# 131:2 (PBP) → 2 (R)
# 132:2 (PBR) → 2 (R)
# 133:2 (PBB) → 2 (R)
# 200:0 (R00) → 0 (0)
# 201:1 (R0P) → 1 (P)
# 202:3 (R0R) → 3 (B)
# 203:2 (R0B) → 2 (R)
# 210:0 (RP0) → 0 (0)
# 211:3 (RPP) → 3 (B)
# 212:1 (RPR) → 1 (P)
# 213:3 (RPB) → 3 (B)
# 220:0 (RR0) → 0 (0)
# 221:2 (RRP) → 2 (R)
# 222:3 (RRR) → 3 (B)
# 223:1 (RRB) → 1 (P)
# 230:3 (RB0) → 3 (B)
# ...
